# %% [markdown]
# ### Overview
# - Association rule learning is a rule-based machine learning method for discovering interesting relations between variables in large databases. It is intended to identify strong rules discovered in databases using some measures of interestingness.
#
#
#  For example, the rule  {onions,potatoes}=> {burger} found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.
#
# ### Some Basic Concepts:
#
# - [Association rule](https://en.wikipedia.org/wiki/Association_rule_learning)
# - [Support](https://en.wikipedia.org/wiki/Association_rule_learning#Useful_Concepts)
# - [Confidence](https://en.wikipedia.org/wiki/Association_rule_learning#Useful_Concepts)
# - [List](https://en.wikipedia.org/wiki/Association_rule_learning#Useful_Concepts)
# - [Conviction](https://en.wikipedia.org/wiki/Association_rule_learning#Useful_Concepts)
#
# - Some useful concepts related to association rule:
#
# ![chart](https://www.researchgate.net/profile/Chulhyun_Kim/publication/228827521/figure/tbl1/AS:669547573026817@1536643989215/Measures-of-interestingness.png)
#
# ![nice example](https://www.researchgate.net/publication/321053532/figure/tbl1/AS:613924688896000@1523382460012/Support-confidence-and-lift-calculation-for-patient-with-diabetes.png)
#
#
#
#
# - Apriori is an algorithm for frequent item set mining and association rule learning over relational databases. It proceeds by identifying the frequent individual items in the database and extending them to larger and larger item sets as long as those item sets appear sufficiently often in the database.
#
#
#
# #### Simple procedure on how Apriori works:
#
#         - Set a minimum support and confidence
#         - Take all the subsets in transaction having support higher than minimum support
#         - Take all rules of these subsets having confidence higher than minimum confidence
#         - Now sort the rules by decreasing lift
#
#
# ()

# %% [markdown]
# # Implenentation using libraries:
#
# Libraries Doc Links:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler.fit_transform
#
# http://rasbt.github.io/mlxtend/
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.colors.ListedColormap.html
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.scatter.html
#
# https://matplotlib.org/3.1.1/api/colors_api.html

# %%
# Implementation using mlxtend



import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules 


# Loading the Data 
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv',encoding='iso-8859-1') 
data.head() 

# Exploring the columns of the data 
data.columns 

# Exploring the different regions of transactions 
data.Country.unique() 

# Stripping extra spaces in the description 
data['Description'] = data['Description'].str.strip() 

# Dropping the rows without any invoice number 
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True) 
data['InvoiceNo'] = data['InvoiceNo'].astype('str') 

# Dropping all transactions which were done on credit 
data = data[~data['InvoiceNo'].str.contains('C')] 

# Transactions done in France 
basket_France = (data[data['Country'] =="France"].groupby(['InvoiceNo', 'Description'])['Quantity'] .sum().unstack().reset_index().fillna(0) .set_index('InvoiceNo')) 



# Defining the hot encoding function to make the data suitable 
# for the concerned libraries 
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# Encoding the datasets 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded 


# Building the model 
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True) 

# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
print(rules.head())
# Out:
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 260  (PLASTERS IN TIN CIRCUS PARADE, RED TOADSTOOL ...
# 272  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 300  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
#
#                          consequents  antecedent support  consequent support  \
# 45                         (POSTAGE)            0.076531            0.765306
# 260                        (POSTAGE)            0.051020            0.765306
# 272                        (POSTAGE)            0.053571            0.765306
# 302  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# 300    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 45   0.076531       1.000  1.306667  0.017961         inf
# 260  0.051020       1.000  1.306667  0.011974         inf
# 272  0.053571       1.000  1.306667  0.012573         inf
# 302  0.099490       0.975  7.644000  0.086474   34.897959
# 300  0.099490       0.975  7.077778  0.085433   34.489796

# %% [markdown]
# ### Implementation using apyori

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori


# Loading the Data 
data = pd.read_csv('https://raw.githubusercontent.com/luoyetx/Apriori/master/data.csv') 
data.head()
# Out:
#    corned_b   peppers bourbon  cracker   chicken    apples      coke
# 0    olives   bourbon    coke   turkey  ice_crea       ham  baguette
# 1    hering  corned_b  olives      ham    turkey   bourbon   peppers
# 2  baguette  sardines  apples  peppers   avocado  ice_crea   bourbon
# 3  baguette      soda  hering  cracker  heineken   peppers    apples
# 4  baguette      soda  hering  cracker  heineken  corned_b       ham

# %%
data.shape
# Out:
# (1000, 7)

# %%
#Converting pandas dataframe into list of lists
records=data.values.tolist()
records
# Out:
# [['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'ham', 'baguette'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'bourbon', 'peppers'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'ice_crea',
#   'bourbon'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'peppers', 'apples'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'corned_b', 'ham'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'ice_crea', 'olives'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'cracker', 'chicken'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'avocado', 'soda'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'ice_crea',
#   'ice_crea'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'steak', 'corned_b'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'steak', 'steak'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'ham', 'hering'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'sardines',
#   'olives'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'hering', 'cracker'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'artichok', 'steak'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'heineken', 'apples'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'soda', 'ham'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'cracker', 'avocado'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bordeaux', 'avocado'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'steak', 'cracker'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'olives', 'cracker'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'steak', 'baguette'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'cracker',
#   'bourbon'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'olives',
#   'cracker'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'chicken',
#   'apples'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'apples', 'baguette'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'coke', 'ice_crea'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'olives', 'ham'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'bordeaux', 'artichok'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'peppers', 'chicken'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'ice_crea', 'bourbon'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'soda', 'olives'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'ham', 'peppers'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'olives', 'cracker'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'steak', 'sardines'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'artichok', 'turkey'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'artichok', 'hering'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'sardines',
#   'peppers'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'bordeaux', 'olives'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'bourbon', 'peppers'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'baguette', 'steak'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'peppers', 'ham'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bordeaux',
#   'cracker'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'ham', 'ice_crea'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'coke', 'apples'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'baguette', 'ham'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'sardines', 'avocado'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'cracker', 'steak'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'bordeaux',
#   'ice_crea'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'olives', 'olives'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'artichok',
#   'baguette'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'corned_b', 'sardines'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'olives',
#   'bourbon'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'bordeaux', 'chicken'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'avocado', 'artichok'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'ham', 'coke'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'corned_b', 'turkey'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'ham', 'ham'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'ice_crea', 'coke'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'turkey', 'turkey'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'avocado', 'bourbon'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'bourbon', 'peppers'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'bordeaux', 'coke'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'bordeaux', 'soda'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'ham', 'steak'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 
],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bourbon',
#   'corned_b'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'bordeaux', 'soda'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'cracker',
#   'sardines'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'bourbon', 'olives'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'ham', 'apples'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'sardines'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'artichok', 'chicken'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'steak', 'apples'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'avocado', 'turkey'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'artichok'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'steak', 'artichok'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'bourbon',
#   'bourbon'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'ice_crea', 'artichok'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'apples', 'ham'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'apples', 'steak'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'peppers', 'cracker'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'hering', 'turkey'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'avocado'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'steak', 'steak'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'corned_b',
#   'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'sardines', 'soda'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'turkey', 'hering'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'soda', 'olives'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'hering', 'steak'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'bordeaux', 'olives'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'olives', 'olives'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'baguette', 'ham'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bourbon', 'heineken'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'bordeaux', 'olives'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'bourbon', 'soda'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'apples',
#   'corned_b'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'olives', 'turkey'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'apples', 'turkey'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'peppers', 'steak'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bourbon',
#   'bourbon'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'turkey', 'turkey'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'hering', 'sardines'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'soda', 'bourbon'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'steak', 'heineken'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bourbon',
#   'chicken'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'bordeaux',
#   'bourbon'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'steak', 'heineken'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'steak'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'apples', 'peppers'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'coke', 'apples'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'ham', 'peppers'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'corned_b', 'turkey'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'coke', 'chicken'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'chicken', 'artichok'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'turkey', 'hering'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'apples', 'cracker'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'cracker', 'chicken'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'soda', 'peppers'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'ice_crea', 'coke'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bordeaux', 'hering'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'heineken', 'bourbon'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'chicken', 'chicken'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'peppers', 'ham'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'sardines',
#   'corned_b'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'peppers', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'cracker', 'artichok'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'avocado', 'ham'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'ham', 'corned_b'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'baguette',
#   'hering'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'soda', 'olives'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'peppers', 'steak'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'turkey'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'steak', 'chicken'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'steak', 'olives'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'peppers', 'corned_b'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'hering', 'heineken'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'bordeaux', 'ice_crea'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'chicken', 'corned_b'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'artichok', 'coke'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'artichok', 'apples'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'peppers', 'sardines'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'apples', 'baguette'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'avocado', 'peppers'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'steak', 'turkey'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'cracker', 'baguette'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'steak', 'sardines'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'bourbon', 'olives'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'bordeaux', 'apples'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'apples', 'olives'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'steak',
#   'sardines'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'sardines', 'ham'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bordeaux', 'chicken'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'olives',
#   'corned_b'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'sardines', 'artichok'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'coke', 'ice_crea'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'bourbon', 'sardines'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'ice_crea', 'steak'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'steak', 'avocado'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bordeaux', 'corned_b'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'avocado'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'artichok'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'ice_crea', 'apples'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'ice_crea', 'corned_b'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'apples', 'olives'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'soda', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'soda', 'coke'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'steak', 'turkey'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'turkey',
#   'bourbon'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'bordeaux', 'avocado'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'turkey'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'peppers', 'chicken'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'heineken', 'ham'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'ham', 'heineken'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'bordeaux',
#   'corned_b'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'coke', 'soda'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'avocado', 'ham'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'coke', 'turkey'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'baguette', 'bourbon'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'bordeaux',
#   'artichok'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'chicken', 'apples'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'ice_crea', 'soda'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'turkey', 'bourbon'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bordeaux', 'peppers'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'artichok', 'apples'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'corned_b', 'chicken'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'chicken'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'chicken',
#   'artichok'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'bourbon', 'peppers'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'chicken'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'peppers', 'cracker'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'apples',
#   'peppers'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 
],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'coke', 'ham'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'avocado',
#   'baguette'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'peppers', 'chicken'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'artichok', 'avocado'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'hering', 'coke'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'ham', 'avocado'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'artichok', 'peppers'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'steak', 'heineken'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'baguette', 'hering'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'peppers', 'ham'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'ice_crea', 'apples'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'corned_b', 'sardines'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'chicken',
#   'cracker'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'ice_crea',
#   'apples'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'artichok', 'apples'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'cracker', 'soda'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'apples', 'sardines'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'turkey', 'ham'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'olives',
#   'chicken'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'sardines', 'peppers'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'soda', 'chicken'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'coke', 'cracker'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'corned_b', 'soda'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'bordeaux', 'ham'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'soda', 'bourbon'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'hering', 'peppers'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'turkey',
#   'chicken'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'ice_crea', 'avocado'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bordeaux', 'olives'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'apples', 'corned_b'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'sardines', 'ham'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'corned_b', 'hering'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'baguette',
#   'apples'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'apples'],
# ...
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'cracker', 'baguette'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bourbon',
#   'apples'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'baguette', 'chicken'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'olives', 'bourbon'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'apples', 'steak'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'heineken', 'heineken'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'apples', 'soda'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'chicken',
#   'peppers'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'soda', 'baguette'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'soda', 'cracker'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'ham', 'bourbon'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bourbon', 'heineken'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bordeaux', 'avocado'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'sardines', 'chicken'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'sardines', 'artichok'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'coke', 'coke'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'ice_crea', 'steak'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'cracker',
#   'cracker'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'baguette', 'turkey'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'olives', 'ice_crea'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'coke', 'soda'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'bordeaux', 'peppers'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'apples',
#   'bourbon'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'bourbon', 'avocado'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'chicken', 'ice_crea'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'turkey', 'olives'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'artichok', 'ham'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'sardines', 'olives'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'apples', 'turkey'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'sardines', 'ice_crea'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'turkey', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'baguette', 'ice_crea'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'chicken',
#   'bourbon'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'soda', 'ice_crea'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'coke', 'corned_b'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'hering',
#   'sardines'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'soda', 'coke'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bordeaux', 'baguette'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'chicken', 'olives'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'apples', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'coke', 'ham'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'hering', 'bourbon'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'turkey', 'ham'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'ice_crea',
#   'steak'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'corned_b',
#   'chicken'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'bordeaux',
#   'cracker'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'ham', 'apples'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'turkey', 'chicken'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'cracker', 'chicken'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'ham', 'artichok'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'steak', 'ham'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'baguette', 'steak'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'apples', 'baguette'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'artichok'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'corned_b',
#   'cracker'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'ham', 'heineken'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'baguette', 'ice_crea'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bordeaux',
#   'cracker'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'ice_crea', 'coke'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'soda', 'olives'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'avocado', 'peppers'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'bourbon', 'ice_crea'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'apples', 'artichok'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'corned_b', 'ham'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'steak', 'hering'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'bordeaux',
#   'corned_b'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'bordeaux',
#   'cracker'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'sardines',
#   'corned_b'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'sardines', 'hering'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'steak', 'ice_crea'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bordeaux', 'ham'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'heineken',
#   'sardines'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'soda', 'sardines'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'apples', 'soda'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bordeaux', 'cracker'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'sardines', 'apples'],
#  ['corned_b',
#   'peppers',
#   'bourbon',
#   'cracker',
#   'chicken',
#   'apples',
#   'baguette'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'corned_b', 'sardines'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'hering'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'soda', 'peppers'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'avocado', 'cracker'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'olives', 'peppers'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'olives', 'avocado'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'chicken', 'ice_crea'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'hering', 'ham'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'steak', 'chicken'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bourbon', 'apples'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'coke', 'steak'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'apples', 'baguette'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'soda', 'artichok'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'peppers',
#   'peppers'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'chicken',
#   'turkey'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'steak',
#   'corned_b'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'artichok', 'sardines'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'hering', 'baguette'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'bourbon', 'ice_crea'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'ice_crea', 'baguette'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'turkey', 'coke'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'turkey', 'cracker'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'turkey', 'baguette'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'hering', 'soda'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'peppers', 'coke'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'olives',
#   'ice_crea'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'chicken', 'apples'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'corned_b', 'steak'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'turkey',
#   'ice_crea'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'artichok', 'turkey'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'bourbon', 'apples'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'sardines', 'chicken'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'sardines', 'cracker'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'corned_b', 'baguette'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'sardines', 'bourbon'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'baguette', 'soda'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'turkey', 'apples'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'coke', 'soda'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'sardines', 'peppers'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'hering', 'apples'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'coke', 'apples'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'ham', 'steak'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'sardines', 'sardines'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'sardines',
#   'apples'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'heineken', 'cracker'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'hering', 'apples'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'chicken', 'bourbon'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'olives', 'soda'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'baguette',
#   'bourbon'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'steak', 'soda'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'steak', 'ham'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'apples', 'corned_b'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'ice_crea', 'ice_crea'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'apples', 'artichok'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'artichok', 'steak'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'turkey', 'artichok'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'artichok', 'steak'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'ham', 'ice_crea'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'ice_crea', 'ice_crea'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'sardines', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'ham', 'avocado'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'heineken', 'soda'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'baguette', 'artichok'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'ice_crea', 'artichok'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'coke', 'apples'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'cracker', 'steak'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'avocado', 'steak'],
#  ['baguette', 'hering', 'avocado', 'artichok', 'heineken', 'ham', 'apples'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'olives', 'corned_b'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'steak', 'baguette'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'chicken', 'corned_b'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'hering', 'apples'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'baguette', 'chicken'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'soda', 'ice_crea'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'apples', 'ice_crea'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'olives', 'bourbon'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'avocado', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'turkey', 'ice_crea'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'ham', 'corned_b'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'bordeaux', 'coke'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'corned_b', 'ham'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bordeaux', 'artichok'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'chicken', 'apples'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'steak'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'olives', 'ham'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'hering', 'artichok'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'coke', 'hering'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'sardines', 'steak'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bourbon', 'avocado'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'steak', 'olives'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'corned_b',
#   'olives'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'baguette', 'olives'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'ice_crea', 'steak'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'artichok', 'cracker'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'bourbon', 'bourbon'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'apples', 'peppers'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'apples', 'soda'],
#  ['baguette',
#   'hering',
#   'avocado',
#   'artichok',
#   'heineken',
#   'chicken',
#   'bourbon'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'peppers', 'cracker'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'apples', 'sardines'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'peppers', 'ham'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'olives', 'avocado'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'corned_b',
#   'olives'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'apples', 'artichok'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'heineken', 'cracker'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'baguette', 'coke'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'olives', 'olives'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'coke', 'apples'],
#  ['baguette', 'sardines', 'apples', 'peppers', 'avocado', 'coke', 'cracker'],
#  ['sardines', 'heineken', 'chicken', 'coke', 'ice_crea', 'ham', 'corned_b'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'chicken', 'soda'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'baguette', 'ham'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'chicken', 'bourbon'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'hering', 'steak'],
#  ['hering', 'corned_b', 'olives', 'ham', 'turkey', 'artichok', 'chicken'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'hering',
#   'ice_crea'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'bordeaux', 'cracker'],
#  ['corned_b', 'peppers', 'bourbon', 'cracker', 'chicken', 'steak', 'apples'],
#  ['baguette', 'soda', 'hering', 'cracker', 'heineken', 'artichok', 'avocado'],
#  ['avocado', 'cracker', 'artichok', 'heineken', 'ham', 'corned_b', 'chicken'],
#  ['soda', 'olives', 'bourbon', 'cracker', 'heineken', 'avocado', 'avocado'],
#  ['baguette',
#   'sardines',
#   'apples',
#   'peppers',
#   'avocado',
#   'ice_crea',
#   'olives'],
#  ['sardines',
#   'heineken',
#   'chicken',
#   'coke',
#   'ice_crea',
#   'corned_b',
#   'peppers'],
#  ['hering', 'corned_b', 'apples', 'olives', 'steak', 'baguette', 'peppers'],
#  ['olives', 'bourbon', 'coke', 'turkey', 'ice_crea', 'peppers', 'peppers']]

# %%
# Building apriori model
association_rules=apriori(records,min_support=0.05,min_confidence=0.7)
results=list(association_rules)

for i in range(5):
    print(results[i])
    print("\n")
# Out:
# RelationRecord(items=frozenset({'heineken', 'artichok'}), support=0.252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'artichok'}), items_add=frozenset({'heineken'}), confidence=0.8262295081967214, lift=1.377049180327869)])
#
#
# RelationRecord(items=frozenset({'ice_crea', 'coke'}), support=0.22, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coke'}), items_add=frozenset({'ice_crea'}), confidence=0.7457627118644068, lift=2.3826284724102456), OrderedStatistic(items_base=frozenset({'ice_crea'}), items_add=frozenset({'coke'}), confidence=0.7028753993610224, lift=2.3826284724102456)])
#
#
# RelationRecord(items=frozenset({'heineken', 'cracker'}), support=0.366, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cracker'}), items_add=frozenset({'heineken'}), confidence=0.7515400410677618, lift=1.2525667351129364)])
#
#
# RelationRecord(items=frozenset({'soda', 'cracker'}), support=0.251, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda'}), items_add=frozenset({'cracker'}), confidence=0.7893081761006289, lift=1.6207560084201824)])
#
#
# RelationRecord(items=frozenset({'heineken', 'soda'}), support=0.257, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda'}), items_add=frozenset({'heineken'}), confidence=0.8081761006289309, lift=1.3469601677148848)])

# %%
for item in results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: heineken -> artichok
# Support: 0.252
# Confidence: 0.8262295081967214
# Lift: 1.377049180327869
# =====================================
# Rule: ice_crea -> coke
# Support: 0.22
# Confidence: 0.7457627118644068
# Lift: 2.3826284724102456
# =====================================
# Rule: heineken -> cracker
# Support: 0.366
# Confidence: 0.7515400410677618
# Lift: 1.2525667351129364
# =====================================
# Rule: soda -> cracker
# Support: 0.251
# Confidence: 0.7893081761006289
# Lift: 1.6207560084201824
# =====================================
# Rule: heineken -> soda
# Support: 0.257
# Confidence: 0.8081761006289309
# Lift: 1.3469601677148848
# =====================================
# Rule: olives -> turkey
# Support: 0.221
# Confidence: 0.7809187279151945
# Lift: 1.6509909681082335
# =====================================
# Rule: apples -> avocado
# Support: 0.112
# Confidence: 0.8057553956834532
# Lift: 2.055498458376156
# =====================================
# Rule: apples -> avocado
# Support: 0.096
# Confidence: 0.7441860465116279
# Lift: 2.0500993016849254
# =====================================
# Rule: apples -> avocado
# Support: 0.092
# Confidence: 0.7301587301587301
# Lift: 2.0114565569111025
# =====================================
# Rule: apples -> baguette
# Support: 0.097
# Confidence: 0.751937984496124
# Lift: 1.9182091441227653
# =====================================
# Rule: apples -> sardines
# Support: 0.095
# Confidence: 0.753968253968254
# Lift: 1.9233884029802395
# =====================================
# Rule: apples -> corned_b
# Support: 0.113
# Confidence: 0.7533333333333334
# Lift: 1.5500685871056243
# =====================================
# Rule: apples -> corned_b
# Support: 0.116
# Confidence: 0.7733333333333334
# Lift: 1.6349541930937284
# =====================================
# Rule: apples -> steak
# Support: 0.102
# Confidence: 0.864406779661017
# Lift: 2.2164276401564535
# =====================================
# Rule: apples -> olives
# Support: 0.114
# Confidence: 0.7261146496815287
# Lift: 1.5351261092632744
# =====================================
# Rule: apples -> steak
# Support: 0.099
# Confidence: 0.8389830508474577
# Lift: 1.7263025737602011
# =====================================
# Rule: apples -> steak
# Support: 0.099
# Confidence: 0.8389830508474577
# Lift: 1.773748521876232
# =====================================
# Rule: apples -> sardines
# Support: 0.091
# Confidence: 0.7054263565891472
# Lift: 2.383197150639011
# =====================================
# Rule: avocado -> baguette
# Support: 0.112
# Confidence: 0.8296296296296296
# Lift: 2.285481073359861
# =====================================
# Rule: avocado -> artichok
# Support: 0.113
# Confidence: 0.7197452229299364
# Lift: 1.9827692091733784
# =====================================
# Rule: avocado -> ham
# Support: 0.113
# Confidence: 0.8828125
# Lift: 2.431990358126722
# =====================================
# Rule: heineken -> avocado
# Support: 0.199
# Confidence: 0.9431279620853081
# Lift: 1.571879936808847
# =====================================
# Rule: avocado -> artichok
# Support: 0.117
# Confidence: 0.7452229299363058
# Lift: 2.052955729852082
# =====================================
# Rule: heineken -> baguette
# Support: 0.123
# Confidence: 0.911111111111111
# Lift: 1.5185185185185184
# =====================================
# Rule: baguette -> artichok
# Support: 0.116
# Confidence: 0.8592592592592593
# Lift: 1.768023167200122
# =====================================
# Rule: heineken -> chicken
# Support: 0.055
# Confidence: 0.7971014492753623
# Lift: 1.3285024154589373
# =====================================
# Rule: ham -> artichok
# Support: 0.101
# Confidence: 0.7890625
# Lift: 1.6202515400410678
# =====================================
# Rule: heineken -> artichok
# Support: 0.144
# Confidence: 0.9171974522292993
# Lift: 1.5286624203821655
# =====================================
# Rule: heineken -> ham
# Support: 0.113
# Confidence: 0.8828125
# Lift: 1.4713541666666667
# =====================================
# Rule: heineken -> artichok
# Support: 0.13
# Confidence: 0.8280254777070064
# Lift: 1.3800424628450108
# =====================================
# Rule: heineken -> soda
# Support: 0.059
# Confidence: 0.9516129032258064
# Lift: 1.586021505376344
# =====================================
# Rule: avocado -> baguette
# Support: 0.128
# Confidence: 0.7529411764705882
# Lift: 1.9207683073229291
# =====================================
# Rule: avocado -> baguette
# Support: 0.102
# Confidence: 0.8095238095238094
# Lift: 2.0651117589893095
# =====================================
# Rule: avocado -> sardines
# Support: 0.101
# Confidence: 0.7952755905511811
# Lift: 2.028764261610156
# =====================================
# Rule: avocado -> ham
# Support: 0.105
# Confidence: 0.7608695652173912
# Lift: 1.5623605035264707
# =====================================
# Rule: heineken -> avocado
# Support: 0.143
# Confidence: 0.8773006134969324
# Lift: 1.462167689161554
# =====================================
# Rule: heineken -> avocado
# Support: 0.117
# Confidence: 0.8478260869565217
# Lift: 1.4130434782608696
# =====================================
# Rule: heineken -> avocado
# Support: 0.134
# Confidence: 0.788235294117647
# Lift: 1.3137254901960784
# =====================================
# Rule: heineken -> avocado
# Support: 0.058
# Confidence: 0.7733333333333334
# Lift: 1.2888888888888892
# =====================================
# Rule: avocado -> sardines
# Support: 0.094
# Confidence: 0.746031746031746
# Lift: 2.5203775203775205
# =====================================
# Rule: heineken -> chicken
# Support: 0.055
# Confidence: 0.7051282051282052
# Lift: 1.1752136752136753
# =====================================
# Rule: heineken -> baguette
# Support: 0.145
# Confidence: 0.8192090395480226
# Lift: 1.3653483992467044
# =====================================
# Rule: hering -> baguette
# Support: 0.128
# Confidence: 0.7231638418079097
# Lift: 1.487991444049197
# =====================================
# Rule: soda -> baguette
# Support: 0.127
# Confidence: 0.7175141242937854
# Lift: 2.2563337241942936
# =====================================
# Rule: heineken -> baguette
# Support: 0.214
# Confidence: 0.8199233716475095
# Lift: 1.6870851268467275
# =====================================
# Rule: heineken -> soda
# Support: 0.138
# Confidence: 0.9019607843137256
# Lift: 1.5032679738562094
# =====================================
# Rule: soda -> baguette
# Support: 0.129
# Confidence: 0.8431372549019608
# Lift: 1.7348503187283144
# =====================================
# Rule: sardines -> baguette
# Support: 0.093
# Confidence: 0.7045454545454545
# Lift: 2.3882896764252695
# =====================================
# Rule: bourbon -> chicken
# Support: 0.112
# Confidence: 0.767123287671233
# Lift: 1.5752018227335378
# =====================================
# Rule: bourbon -> chicken
# Support: 0.1
# Confidence: 0.8130081300813009
# Lift: 2.0224082837843307
# =====================================
# Rule: bourbon -> ice_crea
# Support: 0.117
# Confidence: 0.841726618705036
# Lift: 2.6892224239777507
# =====================================
# Rule: bourbon -> olives
# Support: 0.109
# Confidence: 0.7841726618705035
# Lift: 1.6578703210792887
# =====================================
# Rule: bourbon -> turkey
# Support: 0.098
# Confidence: 0.7050359712230215
# Lift: 2.491293184533645
# =====================================
# Rule: bourbon -> corned_b
# Support: 0.111
# Confidence: 0.7302631578947368
# Lift: 1.4995136712417594
# =====================================
# Rule: bourbon -> corned_b
# Support: 0.096
# Confidence: 0.7007299270072992
# Lift: 1.7431092711624356
# =====================================
# Rule: bourbon -> heineken
# Support: 0.151
# Confidence: 0.719047619047619
# Lift: 1.4764838173462405
# =====================================
# Rule: bourbon -> olives
# Support: 0.131
# Confidence: 0.7081081081081081
# Lift: 1.761462955492806
# =====================================
# Rule: bourbon -> peppers
# Support: 0.116
# Confidence: 0.758169934640523
# Lift: 1.5568171142515872
# =====================================
# Rule: bourbon -> soda
# Support: 0.136
# Confidence: 0.8774193548387097
# Lift: 1.8016824534675764
# =====================================
# Rule: bourbon -> soda
# Support: 0.124
# Confidence: 0.8
# Lift: 1.3333333333333335
# =====================================
# Rule: bourbon -> ice_crea
# Support: 0.108
# Confidence: 0.7448275862068966
# Lift: 1.5746883429321281
# =====================================
# Rule: bourbon -> turkey
# Support: 0.099
# Confidence: 0.7071428571428571
# Lift: 2.2592423550890004
# =====================================
# Rule: bourbon -> soda
# Support: 0.124
# Confidence: 0.8
# Lift: 1.6913319238900637
# =====================================
# Rule: bourbon -> turkey
# Support: 0.127
# Confidence: 0.907142857142857
# Lift: 1.9178495922681968
# =====================================
# Rule: heineken -> chicken
# Support: 0.118
# Confidence: 0.8550724637681159
# Lift: 1.4251207729468598
# =====================================
# Rule: chicken -> ice_crea
# Support: 0.123
# Confidence: 0.8913043478260869
# Lift: 2.8476177246839836
# =====================================
# Rule: sardines -> chicken
# Support: 0.117
# Confidence: 0.8478260869565217
# Lift: 2.86427732079906
# =====================================
# Rule: corned_b -> chicken
# Support: 0.1
# Confidence: 0.7042253521126761
# Lift: 1.4460479509500537
# =====================================
# Rule: corned_b -> chicken
# Support: 0.095
# Confidence: 0.7723577235772358
# Lift: 1.9804044194288095
# =====================================
# Rule: chicken -> peppers
# Support: 0.098
# Confidence: 0.7967479674796748
# Lift: 1.636032787432597
# =====================================
# Rule: soda -> chicken
# Support: 0.053
# Confidence: 0.803030303030303
# Lift: 1.6489328604318336
# =====================================
# Rule: heineken -> chicken
# Support: 0.119
# Confidence: 0.8499999999999999
# Lift: 1.4166666666666665
# =====================================
# Rule: heineken -> sardines
# Support: 0.119
# Confidence: 0.8814814814814814
# Lift: 1.4691358024691357
# =====================================
# Rule: sardines -> chicken
# Support: 0.116
# Confidence: 0.8285714285714285
# Lift: 2.799227799227799
# =====================================
# Rule: heineken -> ice_crea
# Support: 0.139
# Confidence: 0.7988505747126438
# Lift: 2.5522382578678715
# =====================================
# Rule: heineken -> sardines
# Support: 0.12
# Confidence: 0.8163265306122449
# Lift: 1.360544217687075
# =====================================
# Rule: olives -> ice_crea
# Support: 0.114
# Confidence: 0.7702702702702703
# Lift: 2.4609273810551766
# =====================================
# Rule: sardines -> ice_crea
# Support: 0.132
# Confidence: 0.8979591836734695
# Lift: 2.868879181065398
# =====================================
# Rule: turkey -> ice_crea
# Support: 0.106
# Confidence: 0.8907563025210085
# Lift: 2.8458667812172793
# =====================================
# Rule: olives -> turkey
# Support: 0.105
# Confidence: 0.7094594594594594
# Lift: 2.506923885015758
# =====================================
# Rule: corned_b -> peppers
# Support: 0.101
# Confidence: 0.7372262773722628
# Lift: 1.513811657848589
# =====================================
# Rule: ham -> corned_b
# Support: 0.123
# Confidence: 0.7687499999999999
# Lift: 1.58179012345679
# =====================================
# Rule: olives -> ham
# Support: 0.123
# Confidence: 0.7687499999999999
# Lift: 1.6252642706131077
# =====================================
# Rule: ham -> corned_b
# Support: 0.105
# Confidence: 0.7835820895522387
# Lift: 2.5691216050893075
# =====================================
# Rule: olives -> corned_b
# Support: 0.202
# Confidence: 0.8244897959183675
# Lift: 1.7431073909479229
# =====================================
# Rule: steak -> corned_b
# Support: 0.113
# Confidence: 0.849624060150376
# Lift: 1.7481976546304032
# =====================================
# Rule: corned_b -> turkey
# Support: 0.113
# Confidence: 0.8432835820895522
# Lift: 1.735151403476445
# =====================================
# Rule: olives -> steak
# Support: 0.111
# Confidence: 0.8345864661654135
# Lift: 1.764453416840198
# =====================================
# Rule: olives -> corned_b
# Support: 0.122
# Confidence: 0.9104477611940298
# Lift: 1.9248367044271244
# =====================================
# Rule: heineken -> ham
# Support: 0.126
# Confidence: 0.8400000000000001
# Lift: 1.4000000000000001
# =====================================
# Rule: heineken -> hering
# Support: 0.163
# Confidence: 0.8109452736318408
# Lift: 1.351575456053068
# =====================================
# Rule: heineken -> ice_crea
# Support: 0.06
# Confidence: 0.7058823529411764
# Lift: 1.1764705882352942
# =====================================
# Rule: heineken -> olives
# Support: 0.14
# Confidence: 0.7567567567567568
# Lift: 1.2612612612612615
# =====================================
# Rule: heineken -> sardines
# Support: 0.059
# Confidence: 0.7374999999999999
# Lift: 1.2291666666666665
# =====================================
# Rule: heineken -> soda
# Support: 0.234
# Confidence: 0.7358490566037736
# Lift: 2.0105165480977423
# =====================================
# Rule: soda -> hering
# Support: 0.141
# Confidence: 0.7014925373134328
# Lift: 2.205951375199474
# =====================================
# Rule: olives -> soda
# Support: 0.126
# Confidence: 0.7636363636363636
# Lift: 1.5680418144483852
# =====================================
# Rule: soda -> peppers
# Support: 0.053
# Confidence: 0.7910447761194029
# Lift: 1.6243219222164331
# =====================================
# Rule: olives -> ham
# Support: 0.121
# Confidence: 0.75625
# Lift: 1.5988372093023255
# =====================================
# Rule: ham -> turkey
# Support: 0.106
# Confidence: 0.7910447761194029
# Lift: 1.6276641483938332
# =====================================
# Rule: olives -> ham
# Support: 0.121
# Confidence: 0.7658227848101266
# Lift: 2.70608757883437
# =====================================
# Rule: heineken -> soda
# Support: 0.149
# Confidence: 0.8563218390804598
# Lift: 1.4272030651340997
# =====================================
# Rule: heineken -> sardines
# Support: 0.123
# Confidence: 0.8145695364238411
# Lift: 1.3576158940397351
# =====================================
# Rule: heineken -> soda
# Support: 0.127
# Confidence: 0.7696969696969697
# Lift: 1.2828282828282829
# =====================================
# Rule: olives -> steak
# Support: 0.116
# Confidence: 0.778523489932886
# Lift: 1.6459270400272432
# =====================================
# Rule: olives -> turkey
# Support: 0.122
# Confidence: 0.8133333333333334
# Lift: 1.7195207892882314
# =====================================
# Rule: olives -> turkey
# Support: 0.111
# Confidence: 0.7161290322580646
# Lift: 2.5304912800638326
# =====================================
# Rule: apples -> avocado
# Support: 0.092
# Confidence: 0.7131782945736433
# Lift: 3.3171083468541553
# =====================================
# Rule: apples -> avocado
# Support: 0.092
# Confidence: 0.7301587301587301
# Lift: 3.396087117017349
# =====================================
# Rule: apples -> avocado
# Support: 0.09
# Confidence: 0.7142857142857143
# Lift: 5.668934240362812
# =====================================
# Rule: apples -> sardines
# Support: 0.09
# Confidence: 0.7142857142857143
# Lift: 5.13874614594039
# =====================================
# Rule: apples -> olives
# Support: 0.109
# Confidence: 0.7266666666666667
# Lift: 2.8385416666666665
# =====================================
# Rule: apples -> steak
# Support: 0.097
# Confidence: 0.8220338983050848
# Lift: 3.355240401245244
# =====================================
# Rule: apples -> steak
# Support: 0.097
# Confidence: 0.8220338983050848
# Lift: 3.4684974612028894
# =====================================
# Rule: apples -> olives
# Support: 0.097
# Confidence: 0.8220338983050848
# Lift: 3.2110699152542375
# =====================================
# Rule: heineken -> avocado
# Support: 0.104
# Confidence: 0.7703703703703703
# Lift: 3.093856909117953
# =====================================
# Rule: avocado -> baguette
# Support: 0.099
# Confidence: 0.7333333333333333
# Lift: 4.313725490196078
# =====================================
# Rule: avocado -> ham
# Support: 0.099
# Confidence: 0.7734375
# Lift: 4.745015337423313
# =====================================
# Rule: heineken -> avocado
# Support: 0.112
# Confidence: 0.713375796178344
# Lift: 2.864963036860819
# =====================================
# Rule: heineken -> avocado
# Support: 0.111
# Confidence: 0.8671875
# Lift: 3.4826807228915664
# =====================================
# Rule: heineken -> avocado
# Support: 0.113
# Confidence: 0.7197452229299364
# Lift: 2.890543063975648
# =====================================
# Rule: heineken -> baguette
# Support: 0.113
# Confidence: 0.837037037037037
# Lift: 2.906378600823045
# =====================================
# Rule: heineken -> ham
# Support: 0.1
# Confidence: 0.78125
# Lift: 2.134562841530055
# =====================================
# Rule: heineken -> avocado
# Support: 0.119
# Confidence: 0.7
# Lift: 2.6819923371647505
# =====================================
# Rule: avocado -> sardines
# Support: 0.091
# Confidence: 0.7222222222222222
# Lift: 5.4713804713804715
# =====================================
# Rule: heineken -> avocado
# Support: 0.101
# Confidence: 0.7318840579710145
# Lift: 1.9996832185000397
# =====================================
# Rule: heineken -> hering
# Support: 0.125
# Confidence: 0.7062146892655368
# Lift: 2.4521343377275584
# =====================================
# Rule: heineken -> soda
# Support: 0.126
# Confidence: 0.711864406779661
# Lift: 2.769900415485062
# =====================================
# Rule: hering -> soda
# Support: 0.115
# Confidence: 0.7516339869281046
# Lift: 3.7394725717816146
# =====================================
# Rule: heineken -> soda
# Support: 0.126
# Confidence: 0.823529411764706
# Lift: 2.859477124183007
# =====================================
# Rule: corned_b -> bourbon
# Support: 0.092
# Confidence: 0.9484536082474226
# Lift: 1.9475433434238658
# =====================================
# Rule: corned_b -> bourbon
# Support: 0.091
# Confidence: 0.7398373983739838
# Lift: 4.867351305091999
# =====================================
# Rule: bourbon -> chicken
# Support: 0.093
# Confidence: 0.7560975609756098
# Lift: 3.163588121236861
# =====================================
# Rule: bourbon -> olives
# Support: 0.097
# Confidence: 0.829059829059829
# Lift: 1.7527691946296597
# =====================================
# Rule: bourbon -> turkey
# Support: 0.096
# Confidence: 0.8067226890756303
# Lift: 5.563604752245727
# =====================================
# Rule: bourbon -> olives
# Support: 0.095
# Confidence: 0.7983193277310925
# Lift: 3.258446235637112
# =====================================
# Rule: bourbon -> corned_b
# Support: 0.092
# Confidence: 0.8288288288288288
# Lift: 2.8095892502672166
# =====================================
# Rule: bourbon -> olives
# Support: 0.109
# Confidence: 0.7218543046357616
# Lift: 1.5261190372849083
# =====================================
# Rule: bourbon -> soda
# Support: 0.121
# Confidence: 0.7806451612903226
# Lift: 2.132910276749515
# =====================================
# Rule: bourbon -> olives
# Support: 0.108
# Confidence: 0.8244274809160305
# Lift: 2.5925392481636176
# =====================================
# Rule: bourbon -> soda
# Support: 0.107
# Confidence: 0.8045112781954886
# Lift: 2.529909679860027
# =====================================
# Rule: bourbon -> turkey
# Support: 0.096
# Confidence: 0.7619047619047619
# Lift: 3.1098153547133136
# =====================================
# Rule: heineken -> chicken
# Support: 0.116
# Confidence: 0.8405797101449275
# Lift: 4.568367989918085
# =====================================
# Rule: heineken -> sardines
# Support: 0.116
# Confidence: 0.8405797101449275
# Lift: 4.61856983596114
# =====================================
# Rule: sardines -> chicken
# Support: 0.116
# Confidence: 0.8405797101449275
# Lift: 5.566753047317401
# =====================================
# Rule: corned_b -> chicken
# Support: 0.091
# Confidence: 0.7398373983739838
# Lift: 4.377736085053158
# =====================================
# Rule: heineken -> sardines
# Support: 0.116
# Confidence: 0.8285714285714285
# Lift: 4.552590266875981
# =====================================
# Rule: heineken -> sardines
# Support: 0.117
# Confidence: 0.7959183673469389
# Lift: 4.325643300798581
# =====================================
# Rule: olives -> turkey
# Support: 0.095
# Confidence: 0.7983193277310925
# Lift: 5.150447275684468
# =====================================
# Rule: olives -> ham
# Support: 0.118
# Confidence: 0.7374999999999999
# Lift: 2.8808593749999996
# =====================================
# Rule: ham -> corned_b
# Support: 0.102
# Confidence: 0.7611940298507461
# Lift: 4.757462686567163
# =====================================
# Rule: olives -> ham
# Support: 0.104
# Confidence: 0.7761194029850745
# Lift: 4.912148120158699
# =====================================
# Rule: olives -> steak
# Support: 0.109
# Confidence: 0.819548872180451
# Lift: 3.2013627819548867
# =====================================
# Rule: olives -> corned_b
# Support: 0.112
# Confidence: 0.835820895522388
# Lift: 3.264925373134328
# =====================================
# Rule: heineken -> soda
# Support: 0.137
# Confidence: 0.7873563218390806
# Lift: 2.1512467809810945
# =====================================
# Rule: heineken -> olives
# Support: 0.122
# Confidence: 0.7393939393939394
# Lift: 2.0202020202020203
# =====================================
# Rule: olives -> ham
# Support: 0.103
# Confidence: 0.7686567164179103
# Lift: 3.002565298507462
# =====================================
# Rule: apples -> avocado
# Support: 0.09
# Confidence: 0.7142857142857143
# Lift: 7.00280112044818
# =====================================
# Rule: apples -> olives
# Support: 0.097
# Confidence: 0.8220338983050848
# Lift: 4.0694747440845775
# =====================================
# Rule: heineken -> avocado
# Support: 0.099
# Confidence: 0.7333333333333333
# Lift: 5.4726368159203975
# =====================================
# Rule: heineken -> avocado
# Support: 0.099
# Confidence: 0.7734375
# Lift: 5.408653846153847
# =====================================
# Rule: heineken -> soda
# Support: 0.115
# Confidence: 0.7516339869281046
# Lift: 4.611251453546654
# =====================================
# Rule: corned_b -> bourbon
# Support: 0.091
# Confidence: 0.7398373983739838
# Lift: 6.6652017871530065
# =====================================
# Rule: bourbon -> olives
# Support: 0.094
# Confidence: 0.7899159663865547
# Lift: 7.314036725801433
# =====================================
# Rule: bourbon -> olives
# Support: 0.106
# Confidence: 0.7019867549668874
# Lift: 4.254465181617499
# =====================================
# Rule: heineken -> sardines
# Support: 0.116
# Confidence: 0.8405797101449275
# Lift: 6.833981383292094
# =====================================
# Rule: olives -> ham
# Support: 0.102
# Confidence: 0.7611940298507461
# Lift: 6.290859750832613
# =====================================
