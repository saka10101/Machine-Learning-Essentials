# %% [markdown]
# ### Hierarchical Clustering

# %% [markdown]
#  Hierarchical clustering is a method of cluster analysis which seeks to build a hierarchy of clusters. Strategies for hierarchical clustering generally fall into two types:
#
# - Agglomerative: This is a "bottom-up" approach: each observation starts in its own cluster, and pairs of clusters are merged as one moves up the hierarchy
# - Divisive: This is a "top-down" approach: all observations start in one cluster, and splits are performed recursively as one moves down the hierarchy
#
# The results of hierarchical clustering are usually presented in a dendrogram which clearly illustrates the arrangement of the clusters
#
#
# How agglomerative hierarchical clustering work in brief?
#
# Steps:
#
# - STEP 1: Make each data point a single point cluster.ie If there are n point then we have n clusters at beginning
#
# - STEP 2: Take the two closest data point and make them one cluster which now forms n-1 clusters
#
# - STEP 3: Now take two closest cluster and make them one cluster which now forms n-2 clusters
#
# - STEP 4: Repeat Step3 until there is only one cluster
#
#
#
# How devisive hierarchical clustering work in brief?
#
# Steps:
#
# - STEP 1: Take whole data points as a single huge cluster. ie At beginning  we have only one cluster
#
# - STEP 2: Select one random data point by making it one cluster and other remaining points as another cluster.ie There are two clusters now
#
# - STEP 3: Now take closest data point and cluster to make them one cluster
#
# - STEP 4: Repeat Step3 until every data point is a single point cluster
#
#
#
# ![](https://www.researchgate.net/profile/Rahmat_Widia_Sembiring/publication/48194320/figure/fig1/AS:307395533262848@1450300214331/Example-of-a-dendrogram-from-hierarchical-clustering.png)

# %% [markdown]
# ### Implementation of Hierarchical clustering

# %%
# Hierarchical Clustering

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('https://github.com/2blam/ML/raw/master/k_means_clustering/Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values


# Using the dendrogram to find the optimal number of clusters
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)

plt.scatter(X[:,0],X[:,1])
plt.show()
print("\nEach Data point with Cluster label:\n")
for i in range(len(X)):
    print("\nData Point:",X[i],"Cluster Label:",y_hc[i])


# Visualising the clusters
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_hc == 2, 0], X[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# Each Data point with Cluster label:
#
#
# Data Point: [15 39] Cluster Label: 4
#
# Data Point: [15 81] Cluster Label: 3
#
# Data Point: [16  6] Cluster Label: 4
#
# Data Point: [16 77] Cluster Label: 3
#
# Data Point: [17 40] Cluster Label: 4
#
# Data Point: [17 76] Cluster Label: 3
#
# Data Point: [18  6] Cluster Label: 4
#
# Data Point: [18 94] Cluster Label: 3
#
# Data Point: [19  3] Cluster Label: 4
#
# Data Point: [19 72] Cluster Label: 3
#
# Data Point: [19 14] Cluster Label: 4
#
# Data Point: [19 99] Cluster Label: 3
#
# Data Point: [20 15] Cluster Label: 4
#
# Data Point: [20 77] Cluster Label: 3
#
# Data Point: [20 13] Cluster Label: 4
#
# Data Point: [20 79] Cluster Label: 3
#
# Data Point: [21 35] Cluster Label: 4
#
# Data Point: [21 66] Cluster Label: 3
#
# Data Point: [23 29] Cluster Label: 4
#
# Data Point: [23 98] Cluster Label: 3
#
# Data Point: [24 35] Cluster Label: 4
#
# Data Point: [24 73] Cluster Label: 3
#
# Data Point: [25  5] Cluster Label: 4
#
# ...
